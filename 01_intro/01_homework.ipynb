# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '3.0.5'

# %%
df = pd.read_csv('../data/car_fuel_efficiency_2026.csv')

# %%
df.shape
# Out:
# (10000, 11)

# %%
df.head(3)
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5

# %%
df.fuel_type.nunique()
# Out:
# 3

# %%
df['fuel_type'].nunique()
# Out:
# 3

# %%
(df.isnull().sum() > 0).sum()
# Out:
# np.int64(2)

# %%
df.isnull().sum()
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df['fuel_efficiency_mpg'].max()
# Out:
# np.float64(41.2)

# %%
df.horsepower.median()
# Out:
# np.float64(254.0)

# %%
df.horsepower.mode()
# Out:
# 0    252.0
# Name: horsepower, dtype: float64

# %%
hp_mode = df['horsepower'].mode()[0]
df['horsepower'] = df['horsepower'].fillna(hp_mode)

# %%
df['horsepower'].median()
# Out:
# np.float64(252.0)

# %%
df_asia = df[df.origin == 'Asia']

# %%
df_asia_2 = df_asia[['vehicle_weight', 'model_year']]
df_asia_7 = df_asia_2.head(7)

# %%
X = df_asia_7.values
X
# Out:
# array([[4240, 1996],
#        [4310, 1992],
#        [4230, 1997],
#        [4420, 1978],
#        [3950, 2007],
#        [4750, 2021],
#        [4450, 2019]])

# %%
tr_X = np.transpose(X)

# %%
XTX = tr_X.dot(X)
np.linalg.inv(XTX)
# Out:
# array([[ 2.96830537e-06, -6.43071025e-06],
#        [-6.43071025e-06,  1.39675281e-05]])

# %%
lists = [1100, 1300, 800, 900, 1000, 1100, 1200]
y = np.array(lists)

# %%
w = (np.linalg.inv(XTX).dot(tr_X)).dot(y)
w
# Out:
# array([0.13644777, 0.2327492 ])

# %%
w.sum()
# Out:
# np.float64(0.36919696904925486)
